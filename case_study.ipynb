# %% [markdown]
# # basic array operations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('auto-mpg.csv')

# %%
a=np.array(data['mpg'])

# %% [markdown]
# #### 1.

# %%
np.mean(a)
np.median(a)
np.std(a)
# Out:
# np.float64(7.806159061274433)

# %% [markdown]
# #### 2.

# %%
df=data[data['mpg']>25]
np.array(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 df=data[data['mpg']>25]
#       2 np.array(df)
# ----> 3 np.count_nonzero()
#
# TypeError: count_nonzero() missing 1 required positional argument: 'a'

# %% [markdown]
# # Filtering

# %%
data[data['cylinders']>6][['car name']]
# Out:
#                                  car name
# 0               chevrolet chevelle malibu
# 1                       buick skylark 320
# 2                      plymouth satellite
# 3                           amc rebel sst
# 4                             ford torino
# ..                                    ...
# 291         chevrolet malibu classic (sw)
# 292  chrysler lebaron town @ country (sw)
# 298                     cadillac eldorado
# 300     oldsmobile cutlass salon brougham
# 364                 oldsmobile cutlass ls
#
# [103 rows x 1 columns]

# %% [markdown]
# # Statistical Analysis

# %%
np.percentile(data['weight'],25,axis=0)
np.percentile(data['weight'],50)
np.percentile(data['weight'],75)
# Out:
# np.float64(3608.0)

# %% [markdown]
# # Array Manipulation

# %%
a=np.array(data['acceleration'])
a_norm=(a-a.min())/(a.max()-a.min())
print(a)
print(a_norm)
# Out:
# [12.  11.5 11.  12.  10.5 10.   9.   8.5 10.   8.5 10.   8.   9.5 10.
#  15.  15.5 15.5 16.  14.5 20.5 17.5 14.5 17.5 12.5 15.  14.  15.  13.5
#  18.5 14.5 15.5 14.  19.  13.  15.5 15.5 15.5 15.5 12.  11.5 13.5 13.
#  11.5 12.  12.  13.5 19.  15.  14.5 14.  14.  19.5 14.5 19.  18.  19.
#  20.5 15.5 17.  23.5 19.5 16.5 12.  12.  13.5 13.  11.5 11.  13.5 13.5
#  12.5 13.5 12.5 14.  16.  14.  14.5 18.  19.5 18.  16.  17.  14.5 15.
#  16.5 13.  11.5 13.  14.5 12.5 11.5 12.  13.  14.5 11.  11.  11.  16.5
#  18.  16.  16.5 16.  21.  14.  12.5 13.  12.5 15.  19.  19.5 16.5 13.5
#  18.5 14.  15.5 13.   9.5 19.5 15.5 14.  15.5 11.  14.  13.5 11.  16.5
#  17.  16.  17.  19.  16.5 21.  17.  17.  18.  16.5 14.  14.5 13.5 16.
#  15.5 16.5 15.5 14.5 16.5 19.  14.5 15.5 14.  15.  15.5 16.  16.  16.
#  21.  19.5 11.5 14.  14.5 13.5 21.  18.5 19.  19.  15.  13.5 12.  16.
#  17.  16.  18.5 13.5 16.5 17.  14.5 14.  17.  15.  17.  14.5 13.5 17.5
# ...

# %% [markdown]
# # Broadcasting

# %%
df=data['horsepower']=pd.to_numeric(data['horsepower'],errors='coerce')
df_filled=df.fillna(df.mean())
df_filled=df_filled*1.10
df_array=np.array(df_filled)
df_array
# Out:
# array([143.        , 181.5       , 165.        , 165.        ,
#        154.        , 217.8       , 242.        , 236.5       ,
#        247.5       , 209.        , 187.        , 176.        ,
#        165.        , 247.5       , 104.5       , 104.5       ,
#        106.7       ,  93.5       ,  96.8       ,  50.6       ,
#         95.7       ,  99.        , 104.5       , 124.3       ,
#         99.        , 236.5       , 220.        , 231.        ,
#        212.3       ,  96.8       ,  99.        , 104.5       ,
#        114.91632653, 110.        , 115.5       , 110.        ,
#         96.8       , 110.        , 181.5       , 192.5       ,
#        168.3       , 165.        , 198.        , 187.        ,
#        192.5       , 121.        ,  79.2       , 110.        ,
#         96.8       ,  94.6       ,  99.        ,  77.        ,
#         83.6       ,  71.5       ,  75.9       ,  66.        ,
#         77.        , 104.5       ,  88.        ,  59.4       ,
# ...

# %% [markdown]
# # Boolean indexing

# %%
df =data[data['origin']==2][['displacement']]
df_array=np.array(df)
np.average(df_array)
# Out:
# np.float64(109.14285714285714)

# %% [markdown]
# # Matrix Operations

# %%
data['horsepower']=pd.to_numeric(data['horsepower'],errors='coerce')
data['horsepower'].fillna(data['horsepower'].mean(),inplace=True)

df_array=np.array(data[['mpg','horsepower','weight']])
v=np.array([1,0.5,-0.2])
df_array.dot(v)
# Out:
# C:\Users\shebi\AppData\Local\Temp\ipykernel_29780\2360327567.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['horsepower'].fillna(data['horsepower'].mean(),inplace=True)
# array([-617.8       , -641.1       , -594.2       , -595.6       ,
#        -602.8       , -754.2       , -746.8       , -740.9       ,
#        -758.5       , -660.        , -612.6       , -627.8       ,
#        -662.2       , -490.7       , -402.9       , -497.1       ,
# ...

# %% [markdown]
# # sorting

# %%
df_array=np.array(data['model year'])
a=np.argsort(-df_array)
data['car name'].iloc[a[:5]]
# Out:
# 397         chevy s-10
# 396        ford ranger
# 395      dodge rampage
# 394          vw pickup
# 393    ford mustang gl
# Name: car name, dtype: object

# %% [markdown]
# # Correlation

# %%
a=np.array(data['mpg'])
b=np.array(data['weight'])
c=np.corrcoef(a,b)
c[0,1]
# Out:
# np.float64(-0.8317409332443352)

# %% [markdown]
# # Conditional aggregates

# %%
a=np.array(data['mpg'])
b=np.array(data['cylinders'])
uniq=np.unique(b)
arr=[]

for i in uniq:
    mean_mpg=a[b==i].mean()
    arr.append((i,mean_mpg))
for i,j in arr:
    print(f"{i}-->{j}")
# Out:
# 3-->20.55
# 4-->29.28676470588235
# 5-->27.366666666666664
# 6-->19.985714285714284
# 8-->14.963106796116506

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Basic exploration

# %%
data=pd.read_csv('auto-mpg.csv')
data
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
data.head(10)
data.count(axis=0) #rows
data.count(axis=1) #columns
# Out:
# 0      9
# 1      9
# 2      9
# 3      9
# 4      9
#       ..
# 393    9
# 394    9
# 395    9
# 396    9
# 397    9
# Length: 398, dtype: int64

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# ## Filtering and indexing

# %%
data[(data['model year']==75) & (data['weight']<3000)][['car name','weight','mpg']]
# Out:
#               car name  weight   mpg
# 167     toyota corolla    2171  29.0
# 168         ford pinto    2639  23.0
# 169        amc gremlin    2914  20.0
# 170      pontiac astro    2592  23.0
# 171      toyota corona    2702  24.0
# 172  volkswagen dasher    2223  25.0
# 173         datsun 710    2545  24.0
# 174         ford pinto    2984  18.0
# 175  volkswagen rabbit    1937  29.0
# 177         audi 100ls    2694  23.0
# 178        peugeot 504    2957  23.0
# 179        volvo 244dl    2945  22.0
# 180          saab 99le    2671  25.0
# 181   honda civic cvcc    1795  33.0

# %% [markdown]
# ## Handling Missing Data

# %%
data.isnull().sum()
data['horsepower']=pd.to_numeric(data['horsepower'],errors='coerce')
data['horsepower'].fillna(data['horsepower'].mean(),inplace = True)
# Out:
# C:\Users\shebi\AppData\Local\Temp\ipykernel_29780\1275814253.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['horsepower'].fillna(data['horsepower'].mean(),inplace = True)

# %% [markdown]
# ## Data transformation

# %%
data['power to weight ratio']=data['horsepower']/data['weight']
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name  power to weight ratio
# ...

# %% [markdown]
# ## Group By

# %%
a=data.groupby('origin')['mpg'].mean()
a
# Out:
# origin
# 1    20.083534
# 2    27.891429
# 3    30.450633
# Name: mpg, dtype: float64

# %% [markdown]
# ## sort

# %%
data.sort_values(by='mpg',ascending=False).head(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 322  46.6          4          86.0   65.000000    2110          17.9
# 329  44.6          4          91.0   67.000000    1850          13.8
# 325  44.3          4          90.0   48.000000    2085          21.7
# 394  44.0          4          97.0   52.000000    2130          24.6
# 326  43.4          4          90.0   48.000000    2335          23.7
# 244  43.1          4          90.0   48.000000    1985          21.5
# 309  41.5          4          98.0   76.000000    2144          14.7
# 330  40.9          4          85.0  104.469388    1835          17.3
# 324  40.8          4          85.0   65.000000    2110          19.2
# 247  39.4          4          85.0   70.000000    2070          18.6
#
#      model year  origin                         car name  \
# 322          80       3                        mazda glc
# 329          80       3              honda civic 1500 gl
# ...

# %% [markdown]
# ## Apply function

# %%
def performance_score(row):
    return row['mpg']*row['acceleration']/row['weight']
data['performance score']=data.apply(performance_score,axis=1)
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin                   car name  power to weight ratio  \
# ...

# %% [markdown]
# ## visualization preparation

# %%
a=data.groupby('model year')[['mpg','weight','horsepower']].mean()
a
# Out:
#                   mpg       weight  horsepower
# model year
# 70          17.689655  3372.793103  147.827586
# 71          21.250000  2995.428571  106.945335
# 72          18.714286  3237.714286  120.178571
# 73          17.100000  3419.025000  130.475000
# 74          22.703704  2877.925926   94.609977
# 75          20.266667  3176.800000  101.066667
# 76          21.573529  3078.735294  101.117647
# 77          23.375000  2997.357143  105.071429
# 78          24.061111  2861.805556   99.694444
# 79          25.093103  3055.344828  101.206897
# 80          33.696552  2436.655172   79.342716
# 81          30.334483  2522.931034   81.843772
# 82          31.709677  2453.548387   82.208690

# %% [markdown]
# ## Exporting data

# %%
a=data[data['mpg']>30][['mpg','cylinders','horsepower','weight']]
a
a.to_csv('high_mpg_cars.csv')

# %% [markdown]
# ## Finding anomilies

# %%
a=np.array(data['mpg'])
q1=np.percentile(a,25)
q3=np.percentile(a,75)
iqr=q3-q1
lb= q1 -(1.5*iqr)
ub=q3+(1.5*iqr)
data[(data['mpg']< lb) | data['mpg']>ub][['car name','mpg','model year']]
# Out:
# Empty DataFrame
# Columns: [car name, mpg, model year]
# Index: []

# %% [markdown]
# # Matplotlib

# %%
plt.hist(data['mpg'])
plt.xlabel('mpg')
plt.ylabel('count')
plt.show()

# %%
import seaborn as sns
sns.boxplot(x='cylinders',y='mpg',data=data)
plt.xlabel('number of cylinders')
plt.ylabel('mpg')
plt.show()

# %%
plt.scatter(data['horsepower'],data['mpg'])
plt.xlabel('horsepower')
plt.ylabel('mpg')
plt.show()

# %%
sns.regplot(x='weight', y='mpg', data=data, scatter_kws={'alpha':0.6}, line_kws={"color": "red"})
plt.title('Relationship Between Car Weight and MPG')
plt.xlabel('Weight')
plt.ylabel('Miles Per Gallon (MPG)')
# Out:
# Text(0, 0.5, 'Miles Per Gallon (MPG)')

# %%
a=data.groupby('model year')['mpg'].mean()
plt.plot(a.index,a.values)
plt.xlabel('model year')
plt.ylabel('mpg')
plt.show()

# %%
a=data['origin'].value_counts().sort_index()
plt.bar(a.index,a.values)
plt.xlabel('origin')
plt.ylabel('number of cars')
# Out:
# Text(0, 0.5, 'number of cars')

# %%
grouped_acc = [data[data['cylinders'] == cyl]['acceleration'] for cyl in sorted(data['cylinders'].unique())]

cylinder_labels = sorted(data['cylinders'].unique())

plt.figure(figsize=(8, 6))
plt.boxplot(grouped_acc, labels=cylinder_labels)

plt.title('Acceleration Distribution by Number of Cylinders')
plt.xlabel('Number of Cylinders')
plt.ylabel('Acceleration')
# Out:
# C:\Users\shebi\AppData\Local\Temp\ipykernel_29780\1036338472.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(grouped_acc, labels=cylinder_labels)
# Text(0, 0.5, 'Acceleration')

# %%
car_counts_by_year = data['model year'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.bar(car_counts_by_year.index, car_counts_by_year.values, color='lightcoral')
plt.xlabel('Model Year')
plt.ylabel('Number of Cars')
plt.title('Number of Car Entries by Model Year')
plt.grid(axis='y')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

ax.scatter(data['weight'], data['horsepower'], data['mpg'], c='teal', alpha=0.7)

ax.set_xlabel('Weight')
ax.set_ylabel('Horsepower')
ax.set_zlabel('MPG')
ax.set_title('3D Scatter Plot of Weight, Horsepower, and MPG')

plt.show()

# %%
top_10 = data.sort_values(by='mpg', ascending=False).head(10)

plt.figure(figsize=(10, 6))
plt.barh(top_10['car name'], top_10['mpg'], color='mediumseagreen')
plt.xlabel('MPG')
plt.title('Top 10 Fuel Efficient Cars')
plt.gca().invert_yaxis()
plt.show()
